# %% [markdown]
# # 4.1 字符问题

# %%
from PIL import Image

Image.open("./img/码位和字节序列.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=797x242>

# %% [markdown]
# 把码位转换成字节序列的过程叫做**编码**，字节序列转成码位的过程叫做**解码**

# %% [markdown]
# > 示例 4-1 编码和解码

# %%
s = 'café'

# %%
len(s)
# Out:
# 4

# %%
b = s.encode('utf8')

# %%
b
# Out:
# b'caf\xc3\xa9'

# %%
len(b)
# Out:
# 5

# %%
b.decode()
# Out:
# 'café'
